# %%
import json
import os
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import torch
import numpy as np
from tqdm.auto import tqdm

# Load categories
categories_path = '/scratch/ssd004/scratch/junejory/categories.json'
with open(categories_path, 'r') as f:
    categories = json.load(f)

# Generate sentences for each category
clip_labels = [f"a photo of a {category['name']}" for category in categories]

# Load annotations
annotations_path = '/scratch/ssd004/scratch/junejory/val2019.json'
with open(annotations_path, 'r') as f:
    annotations = json.load(f)

# %%
clip_labels
# Out:
# ['a photo of a Amanita vaginata',
#  'a photo of a Amanita flavoconia',
#  'a photo of a Amanita calyptroderma',
#  'a photo of a Amanita jacksonii',
#  'a photo of a Amanita phalloides',
#  'a photo of a Amanita muscaria',
#  'a photo of a Amanita bisporigera',
#  'a photo of a Amanita gemmata',
#  'a photo of a Amanita pantherina',
#  'a photo of a Amanita velosa',
#  'a photo of a Amanita augusta',
#  'a photo of a Amanita rubescens',
#  'a photo of a Cicindela aurulenta',
#  'a photo of a Cicindela punctulata',
#  'a photo of a Cicindela ocellata',
#  'a photo of a Cicindela campestris',
#  'a photo of a Cicindela oregona',
#  'a photo of a Cicindela tranquebarica',
#  'a photo of a Cicindela formosa',
#  'a photo of a Cicindela scutellaris',
#  'a photo of a Cicindela duodecimguttata',
#  'a photo of a Cicindela sexguttata',
#  'a photo of a Cicindela repanda',
#  'a photo of a Argia sedula',
#  'a photo of a Argia tibialis',
#  'a photo of a Argia plana',
#  'a photo of a Argia translata',
#  'a photo of a Argia moesta',
#  'a photo of a Argia nahuana',
#  'a photo of a Argia vivida',
#  'a photo of a Argia immunda',
#  'a photo of a Argia apicalis',
#  'a photo of a Argia fumipennis',
#  'a photo of a Enallagma geminatum',
#  'a photo of a Enallagma carunculatum',
#  'a photo of a Enallagma civile',
#  'a photo of a Enallagma aspersum',
#  'a photo of a Enallagma basidens',
#  'a photo of a Enallagma exsulans',
#  'a photo of a Enallagma signatum',
#  'a photo of a Enallagma traviatum',
#  'a photo of a Enallagma vesperum',
#  'a photo of a Enallagma cyathigerum',
#  'a photo of a Libellula quadrimaculata',
#  'a photo of a Libellula depressa',
#  'a photo of a Libellula luctuosa',
#  'a photo of a Libellula needhami',
#  'a photo of a Libellula cyanea',
#  'a photo of a Libellula croceipennis',
#  'a photo of a Libellula auripennis',
#  'a photo of a Libellula comanche',
#  'a photo of a Libellula saturata',
#  'a photo of a Libellula semifasciata',
#  'a photo of a Libellula vibrans',
#  'a photo of a Libellula incesta',
#  'a photo of a Libellula fulva',
#  'a photo of a Libellula forensis',
#  'a photo of a Libellula pulchella',
#  'a photo of a Orthetrum cancellatum',
#  'a photo of a Orthetrum caledonicum',
#  'a photo of a Orthetrum triangulare',
#  'a photo of a Orthetrum chrysis',
#  'a photo of a Orthetrum coerulescens',
#  'a photo of a Orthetrum glaucum',
#  'a photo of a Orthetrum sabina',
#  'a photo of a Orthetrum pruinosum',
#  'a photo of a Orthetrum albistylum',
#  'a photo of a Orthetrum brunneum',
#  'a photo of a Sympetrum vicinum',
#  'a photo of a Sympetrum corruptum',
#  'a photo of a Sympetrum fonscolombii',
#  'a photo of a Sympetrum costiferum',
#  'a photo of a Sympetrum danae',
#  'a photo of a Sympetrum pallipes',
#  'a photo of a Sympetrum semicinctum',
#  'a photo of a Sympetrum ambiguum',
#  'a photo of a Sympetrum sanguineum',
#  'a photo of a Sympetrum obtrusum',
#  'a photo of a Sympetrum illotum',
#  'a photo of a Sympetrum striolatum',
#  'a photo of a Junonia orithya',
#  'a photo of a Junonia coenia',
#  'a photo of a Junonia oenone',
#  'a photo of a Junonia atlites',
#  'a photo of a Junonia hierta',
#  'a photo of a Junonia evarete',
#  'a photo of a Junonia almana',
#  'a photo of a Junonia genoveva',
#  'a photo of a Junonia iphita',
#  'a photo of a Junonia hedonia',
#  'a photo of a Junonia lemonias',
#  'a photo of a Papilio rutulus',
#  'a photo of a Papilio glaucus',
#  'a photo of a Papilio multicaudata',
#  'a photo of a Papilio garamas',
#  'a photo of a Papilio troilus',
#  'a photo of a Papilio eurymedon',
#  'a photo of a Papilio palamedes',
#  'a photo of a Papilio canadensis',
#  'a photo of a Papilio demoleus',
#  'a photo of a Papilio machaon',
#  'a photo of a Papilio polyxenes',
#  'a photo of a Papilio demodocus',
#  'a photo of a Papilio zelicaon',
#  'a photo of a Papilio cresphontes',
#  'a photo of a Papilio anchisiades',
#  'a photo of a Papilio thoas',
#  'a photo of a Papilio rumiko',
#  'a photo of a Papilio xuthus',
#  'a photo of a Papilio polytes',
#  'a photo of a Papilio helenus',
#  'a photo of a Papilio protenor',
#  'a photo of a Papilio memnon',
#  'a photo of a Papilio paris',
#  'a photo of a Bombus terrestris',
#  'a photo of a Bombus terricola',
#  'a photo of a Bombus pensylvanicus',
#  'a photo of a Bombus californicus',
#  'a photo of a Bombus pascuorum',
#  'a photo of a Bombus fervidus',
#  'a photo of a Bombus sonorus',
#  'a photo of a Bombus vosnesenskii',
#  'a photo of a Bombus mixtus',
#  'a photo of a Bombus impatiens',
#  'a photo of a Bombus ternarius',
#  'a photo of a Bombus huntii',
#  'a photo of a Bombus perplexus',
#  'a photo of a Bombus bimaculatus',
#  'a photo of a Bombus bifarius',
#  'a photo of a Bombus vagans',
#  'a photo of a Bombus hypnorum',
#  'a photo of a Bombus melanopygus',
#  'a photo of a Bombus lapidarius',
#  'a photo of a Bombus auricomus',
#  'a photo of a Bombus nevadensis',
#  'a photo of a Bombus griseocollis',
#  'a photo of a Bombus rufocinctus',
#  'a photo of a Bombus citrinus',
#  'a photo of a Bombus borealis',
#  'a photo of a Polistes carnifex',
#  'a photo of a Polistes exclamans',
#  'a photo of a Polistes instabilis',
#  'a photo of a Polistes annularis',
#  'a photo of a Polistes chinensis',
#  'a photo of a Polistes dominula',
#  'a photo of a Polistes major',
#  'a photo of a Polistes rubiginosus',
#  'a photo of a Polistes fuscatus',
#  'a photo of a Polistes carolina',
#  'a photo of a Polistes apachus',
#  'a photo of a Polistes metricus',
#  'a photo of a Polistes aurifer',
#  'a photo of a Polistes dorsalis',
#  'a photo of a Lithobates sphenocephalus',
#  'a photo of a Lithobates grylio',
#  'a photo of a Lithobates clamitans',
#  'a photo of a Lithobates berlandieri',
#  'a photo of a Lithobates septentrionalis',
#  'a photo of a Lithobates pipiens',
#  'a photo of a Lithobates palustris',
#  'a photo of a Lithobates sylvaticus',
#  'a photo of a Lithobates catesbeianus',
#  'a photo of a Lithobates blairi',
#  'a photo of a Sceloporus poinsettii',
#  'a photo of a Sceloporus olivaceus',
#  'a photo of a Sceloporus occidentalis',
#  'a photo of a Sceloporus cowlesi',
#  'a photo of a Sceloporus graciosus',
#  'a photo of a Sceloporus magister',
#  'a photo of a Sceloporus tristichus',
#  'a photo of a Sceloporus spinosus',
#  'a photo of a Sceloporus cyanogenys',
#  'a photo of a Sceloporus variabilis',
#  'a photo of a Sceloporus undulatus',
#  'a photo of a Sceloporus torquatus',
#  'a photo of a Sceloporus grammicus',
#  'a photo of a Sceloporus clarkii',
#  'a photo of a Sceloporus orcutti',
#  'a photo of a Sceloporus uniformis',
#  'a photo of a Sceloporus jarrovii',
#  'a photo of a Sceloporus consobrinus',
#  'a photo of a Crotalus oreganus',
#  'a photo of a Crotalus adamanteus',
#  'a photo of a Crotalus lepidus',
#  'a photo of a Crotalus pyrrhus',
#  'a photo of a Crotalus viridis',
#  'a photo of a Crotalus atrox',
#  'a photo of a Crotalus cerastes',
#  'a photo of a Crotalus horridus',
#  'a photo of a Crotalus molossus',
#  'a photo of a Crotalus scutulatus',
#  'a photo of a Crotalus ruber',
#  'a photo of a Thamnophis sirtalis',
#  'a photo of a Thamnophis cyrtopsis',
#  'a photo of a Thamnophis proximus',
#  'a photo of a Thamnophis marcianus',
#  'a photo of a Thamnophis saurita',
#  'a photo of a Thamnophis ordinoides',
#  'a photo of a Thamnophis atratus',
#  'a photo of a Thamnophis radix',
#  'a photo of a Thamnophis hammondii',
#  'a photo of a Thamnophis elegans',
#  'a photo of a Icterus bullockii',
#  'a photo of a Icterus pustulatus',
#  'a photo of a Icterus gularis',
#  'a photo of a Icterus cucullatus',
#  'a photo of a Icterus parisorum',
#  'a photo of a Icterus wagleri',
#  'a photo of a Icterus abeillei',
#  'a photo of a Icterus galbula',
#  'a photo of a Icterus graduacauda',
#  'a photo of a Icterus spurius',
#  'a photo of a Corvus corax',
#  'a photo of a Corvus monedula',
#  'a photo of a Corvus ossifragus',
#  'a photo of a Corvus cryptoleucus',
#  'a photo of a Corvus splendens',
#  'a photo of a Corvus albus',
#  'a photo of a Corvus cornix',
#  'a photo of a Corvus corone',
#  'a photo of a Corvus caurinus',
#  'a photo of a Corvus frugilegus',
#  'a photo of a Corvus brachyrhynchos',
#  'a photo of a Corvus macrorhynchos',
#  'a photo of a Turdus iliacus',
#  'a photo of a Turdus philomelos',
#  'a photo of a Turdus pilaris',
#  'a photo of a Turdus fuscater',
#  'a photo of a Turdus rufiventris',
#  'a photo of a Turdus viscivorus',
#  'a photo of a Turdus ignobilis',
#  'a photo of a Turdus grayi',
#  'a photo of a Turdus merula',
#  'a photo of a Turdus rufopalliatus',
#  'a photo of a Turdus migratorius',
#  'a photo of a Setophaga pensylvanica',
#  'a photo of a Setophaga petechia',
#  'a photo of a Setophaga tigrina',
#  'a photo of a Setophaga americana',
#  'a photo of a Setophaga cerulea',
#  'a photo of a Setophaga magnolia',
#  'a photo of a Setophaga pitiayumi',
#  'a photo of a Setophaga fusca',
#  'a photo of a Setophaga castanea',
#  'a photo of a Setophaga virens',
#  'a photo of a Setophaga occidentalis',
#  'a photo of a Setophaga townsendi',
#  'a photo of a Setophaga nigrescens',
#  'a photo of a Setophaga ruticilla',
#  'a photo of a Setophaga palmarum',
#  'a photo of a Setophaga discolor',
#  'a photo of a Setophaga caerulescens',
#  'a photo of a Setophaga citrina',
#  'a photo of a Setophaga striata',
#  'a photo of a Setophaga pinus',
#  'a photo of a Setophaga coronata',
#  'a photo of a Setophaga dominica',
#  'a photo of a Vireo philadelphicus',
#  'a photo of a Vireo flavifrons',
#  'a photo of a Vireo olivaceus',
#  'a photo of a Vireo plumbeus',
#  'a photo of a Vireo bellii',
#  'a photo of a Vireo griseus',
#  'a photo of a Vireo solitarius',
#  'a photo of a Vireo cassinii',
#  'a photo of a Vireo huttoni',
#  'a photo of a Vireo gilvus',
#  'a photo of a Larus glaucoides',
#  'a photo of a Larus marinus',
#  'a photo of a Larus hyperboreus',
#  'a photo of a Larus occidentalis',
#  'a photo of a Larus glaucescens  occidentalis',
#  'a photo of a Larus heermanni',
#  'a photo of a Larus michahellis',
#  'a photo of a Larus livens',
#  'a photo of a Larus canus',
#  'a photo of a Larus glaucescens',
#  'a photo of a Larus dominicanus',
#  'a photo of a Larus fuscus',
#  'a photo of a Larus argentatus',
#  'a photo of a Larus delawarensis',
#  'a photo of a Larus californicus',
#  'a photo of a Calidris minutilla',
#  'a photo of a Calidris alpina',
#  'a photo of a Calidris alba',
#  'a photo of a Calidris pusilla',
#  'a photo of a Calidris fuscicollis',
#  'a photo of a Calidris canutus',
#  'a photo of a Calidris mauri',
#  'a photo of a Calidris subruficollis',
#  'a photo of a Calidris pugnax',
#  'a photo of a Calidris virgata',
#  'a photo of a Calidris himantopus',
#  'a photo of a Calidris bairdii',
#  'a photo of a Calidris melanotos',
#  'a photo of a Calidris maritima',
#  'a photo of a Tringa flavipes',
#  'a photo of a Tringa semipalmata',
#  'a photo of a Tringa incana',
#  'a photo of a Tringa glareola',
#  'a photo of a Tringa ochropus',
#  'a photo of a Tringa melanoleuca',
#  'a photo of a Tringa erythropus',
#  'a photo of a Tringa stagnatilis',
#  'a photo of a Tringa nebularia',
#  'a photo of a Tringa totanus',
#  'a photo of a Tringa solitaria',
#  'a photo of a Charadrius obscurus',
#  'a photo of a Charadrius melodus',
#  'a photo of a Charadrius alexandrinus',
#  'a photo of a Charadrius hiaticula',
#  'a photo of a Charadrius semipalmatus',
#  'a photo of a Charadrius wilsonia',
#  'a photo of a Charadrius vociferus',
#  'a photo of a Charadrius nivosus',
#  'a photo of a Charadrius tricollaris',
#  'a photo of a Charadrius dubius',
#  'a photo of a Charadrius bicinctus',
#  'a photo of a Buteo jamaicensis',
#  'a photo of a Buteo swainsoni',
#  'a photo of a Buteo lagopus',
#  'a photo of a Buteo lineatus',
#  'a photo of a Buteo plagiatus',
#  'a photo of a Buteo buteo',
#  'a photo of a Buteo albonotatus',
#  'a photo of a Buteo regalis',
#  'a photo of a Buteo brachyurus',
#  'a photo of a Buteo platypterus',
#  'a photo of a Lysimachia terrestris',
#  'a photo of a Lysimachia punctata',
#  'a photo of a Lysimachia vulgaris',
#  'a photo of a Lysimachia latifolia',
#  'a photo of a Lysimachia quadriflora',
#  'a photo of a Lysimachia arvensis',
#  'a photo of a Lysimachia quadrifolia',
#  'a photo of a Lysimachia nummularia',
#  'a photo of a Lysimachia ciliata',
#  'a photo of a Lysimachia europaea',
#  'a photo of a Lysimachia thyrsiflora',
#  'a photo of a Lysimachia borealis',
#  'a photo of a Lysimachia maritima',
#  'a photo of a Vaccinium arboreum',
#  'a photo of a Vaccinium oxycoccos',
#  'a photo of a Vaccinium ovatum',
#  'a photo of a Vaccinium stamineum',
#  'a photo of a Vaccinium parvifolium',
#  'a photo of a Vaccinium macrocarpon',
#  'a photo of a Vaccinium myrtillus',
#  'a photo of a Vaccinium myrtilloides',
#  'a photo of a Vaccinium corymbosum',
#  'a photo of a Vaccinium angustifolium',
#  'a photo of a Vaccinium uliginosum',
#  'a photo of a Vaccinium vitis-idaea',
#  'a photo of a Cirsium occidentale',
#  'a photo of a Cirsium muticum',
#  'a photo of a Cirsium arvense',
#  'a photo of a Cirsium horridulum',
#  'a photo of a Cirsium oleraceum',
#  'a photo of a Cirsium palustre',
#  'a photo of a Cirsium undulatum',
#  'a photo of a Cirsium vulgare',
#  'a photo of a Cirsium discolor',
#  'a photo of a Cirsium texanum',
#  'a photo of a Symphyotrichum pilosum',
#  'a photo of a Symphyotrichum patens',
#  'a photo of a Symphyotrichum subulatum',
#  'a photo of a Symphyotrichum ericoides',
#  'a photo of a Symphyotrichum chilense',
#  'a photo of a Symphyotrichum divaricatum',
#  'a photo of a Symphyotrichum laeve',
#  'a photo of a Symphyotrichum lateriflorum',
#  'a photo of a Symphyotrichum cordifolium',
#  'a photo of a Symphyotrichum puniceum',
#  'a photo of a Symphyotrichum novae-angliae',
#  'a photo of a Symphyotrichum drummondii',
#  'a photo of a Symphyotrichum lanceolatum',
#  'a photo of a Solidago nemoralis',
#  'a photo of a Solidago gigantea',
#  'a photo of a Solidago rugosa',
#  'a photo of a Solidago altissima',
#  'a photo of a Solidago sempervirens',
#  'a photo of a Solidago virgaurea',
#  'a photo of a Solidago canadensis',
#  'a photo of a Solidago flexicaulis',
#  'a photo of a Solidago juncea',
#  'a photo of a Solidago velutina',
#  'a photo of a Solidago caesia',
#  'a photo of a Solidago bicolor',
#  'a photo of a Solidago ptarmicoides',
#  'a photo of a Solidago rigida',
#  'a photo of a Artemisia tridentata',
#  'a photo of a Artemisia californica',
#  'a photo of a Artemisia douglasiana',
#  'a photo of a Artemisia vulgaris',
#  'a photo of a Artemisia pycnocephala',
#  'a photo of a Artemisia filifolia',
#  'a photo of a Artemisia ludoviciana',
#  'a photo of a Artemisia campestris',
#  'a photo of a Artemisia dracunculus',
#  'a photo of a Artemisia frigida',
#  'a photo of a Acer platanoides',
#  'a photo of a Acer glabrum',
#  'a photo of a Acer saccharum',
#  'a photo of a Acer grandidentatum',
#  'a photo of a Acer negundo',
#  'a photo of a Acer macrophyllum',
#  'a photo of a Acer pseudoplatanus',
#  'a photo of a Acer campestre',
#  'a photo of a Acer rubrum',
#  'a photo of a Acer saccharinum',
#  'a photo of a Acer spicatum',
#  'a photo of a Acer circinatum',
#  'a photo of a Acer nigrum',
#  'a photo of a Acer floridanum',
#  'a photo of a Acer ginnala',
#  'a photo of a Acer pensylvanicum',
#  'a photo of a Trifolium subterraneum',
#  'a photo of a Trifolium arvense',
#  'a photo of a Trifolium incarnatum',
#  'a photo of a Trifolium willdenovii',
#  'a photo of a Trifolium hybridum',
#  'a photo of a Trifolium hirtum',
#  'a photo of a Trifolium campestre',
#  'a photo of a Trifolium repens',
#  'a photo of a Trifolium angustifolium',
#  'a photo of a Trifolium pratense',
#  'a photo of a Trifolium dubium',
#  'a photo of a Trifolium aureum',
#  'a photo of a Trifolium depauperatum',
#  'a photo of a Lupinus albifrons',
#  'a photo of a Lupinus arizonicus',
#  'a photo of a Lupinus polyphyllus',
#  'a photo of a Lupinus nootkatensis',
#  'a photo of a Lupinus hirsutissimus',
#  'a photo of a Lupinus texensis',
#  'a photo of a Lupinus arboreus',
#  'a photo of a Lupinus succulentus',
#  'a photo of a Lupinus bicolor',
#  'a photo of a Lupinus nanus',
#  'a photo of a Lupinus microcarpus',
#  'a photo of a Lupinus argenteus',
#  'a photo of a Lupinus perennis',
#  'a photo of a Cornus nuttallii',
#  'a photo of a Cornus mas',
#  'a photo of a Cornus sericea',
#  'a photo of a Cornus sanguinea',
#  'a photo of a Cornus canadensis',
#  'a photo of a Cornus drummondii',
#  'a photo of a Cornus florida',
#  'a photo of a Cornus alternifolia',
#  'a photo of a Cornus kousa',
#  'a photo of a Cornus racemosa',
#  'a photo of a Cornus unalaschkensis',
#  'a photo of a Cornus rugosa',
#  'a photo of a Cornus amomum',
#  'a photo of a Ribes malvaceum',
#  'a photo of a Ribes sanguineum',
#  'a photo of a Ribes roezlii',
#  'a photo of a Ribes aureum',
#  'a photo of a Ribes americanum',
#  'a photo of a Ribes cynosbati',
#  'a photo of a Ribes cereum',
#  'a photo of a Ribes indecorum',
#  'a photo of a Ribes bracteosum',
#  'a photo of a Ribes speciosum',
#  'a photo of a Lonicera morrowii',
#  'a photo of a Lonicera tatarica',
#  'a photo of a Lonicera ciliosa',
#  'a photo of a Lonicera sempervirens',
#  'a photo of a Lonicera dioica',
#  'a photo of a Lonicera canadensis',
#  'a photo of a Lonicera hispidula',
#  'a photo of a Lonicera xylosteum',
#  'a photo of a Lonicera periclymenum',
#  'a photo of a Lonicera japonica',
#  'a photo of a Lonicera maackii',
#  'a photo of a Lonicera involucrata',
#  'a photo of a Lonicera subspicata',
#  'a photo of a Viburnum prunifolium',
#  'a photo of a Viburnum edule',
#  'a photo of a Viburnum rafinesquianum',
#  'a photo of a Viburnum lentago',
#  'a photo of a Viburnum acerifolium',
#  'a photo of a Viburnum tinus',
#  'a photo of a Viburnum nudum',
#  'a photo of a Viburnum lantana',
#  'a photo of a Viburnum lantanoides',
#  'a photo of a Viburnum rufidulum',
#  'a photo of a Viburnum opulus',
#  'a photo of a Viburnum dentatum',
#  'a photo of a Oenothera suffrutescens',
#  'a photo of a Oenothera biennis',
#  'a photo of a Oenothera speciosa',
#  'a photo of a Oenothera macrocarpa',
#  'a photo of a Oenothera rosea',
#  'a photo of a Oenothera cespitosa',
#  'a photo of a Oenothera curtiflora',
#  'a photo of a Oenothera laciniata',
#  'a photo of a Oenothera drummondii',
#  'a photo of a Oenothera triloba',
#  'a photo of a Oenothera elata',
#  'a photo of a Oenothera suffulta',
#  'a photo of a Oenothera gaura',
#  'a photo of a Opuntia ficus-indica',
#  'a photo of a Opuntia robusta',
#  'a photo of a Opuntia rufida',
#  'a photo of a Opuntia cespitosa',
#  'a photo of a Opuntia basilaris',
#  'a photo of a Opuntia phaeacantha',
#  'a photo of a Opuntia polyacantha',
#  'a photo of a Opuntia littoralis',
#  'a photo of a Opuntia microdasys',
#  'a photo of a Opuntia engelmannii',
#  'a photo of a Opuntia chlorotica',
#  'a photo of a Opuntia macrocentra',
#  'a photo of a Opuntia humifusa',
#  'a photo of a Opuntia fragilis',
#  'a photo of a Opuntia macrorhiza',
#  'a photo of a Cylindropuntia imbricata',
#  'a photo of a Cylindropuntia spinosior',
#  'a photo of a Cylindropuntia prolifera',
#  'a photo of a Cylindropuntia ganderi',
#  'a photo of a Cylindropuntia californica',
#  'a photo of a Cylindropuntia fulgida',
#  'a photo of a Cylindropuntia ramosissima',
#  'a photo of a Cylindropuntia versicolor',
#  'a photo of a Cylindropuntia leptocaulis',
#  'a photo of a Cylindropuntia cholla',
#  'a photo of a Cylindropuntia whipplei',
#  'a photo of a Cylindropuntia echinocarpa',
#  'a photo of a Cylindropuntia acanthocarpa',
#  'a photo of a Cylindropuntia bigelovii',
#  'a photo of a Silene latifolia',
#  'a photo of a Silene laciniata',
#  'a photo of a Silene acaulis',
#  'a photo of a Silene flos-cuculi',
#  'a photo of a Silene virginica',
#  'a photo of a Silene dioica',
#  'a photo of a Silene coronaria',
#  'a photo of a Silene regia',
#  'a photo of a Silene uniflora',
#  'a photo of a Silene gallica',
#  'a photo of a Silene vulgaris',
#  'a photo of a Silene stellata',
#  'a photo of a Persicaria lapathifolia',
#  'a photo of a Persicaria longiseta',
#  'a photo of a Persicaria perfoliata',
#  'a photo of a Persicaria maculosa',
#  'a photo of a Persicaria capitata',
#  'a photo of a Persicaria amphibia',
#  'a photo of a Persicaria hydropiperoides',
#  'a photo of a Persicaria pensylvanica',
#  'a photo of a Persicaria punctata',
#  'a photo of a Persicaria chinensis',
#  'a photo of a Persicaria sagittata',
#  'a photo of a Persicaria virginiana',
#  'a photo of a Asclepias fascicularis',
#  'a photo of a Asclepias exaltata',
#  'a photo of a Asclepias incarnata',
#  'a photo of a Asclepias purpurascens',
#  'a photo of a Asclepias eriocarpa',
#  'a photo of a Asclepias variegata',
#  'a photo of a Asclepias hirtella',
#  'a photo of a Asclepias lanceolata',
#  'a photo of a Asclepias cordifolia',
#  'a photo of a Asclepias quadrifolia',
#  'a photo of a Asclepias perennis',
#  'a photo of a Asclepias subulata',
#  'a photo of a Asclepias speciosa',
#  'a photo of a Asclepias latifolia',
#  'a photo of a Asclepias tuberosa',
#  'a photo of a Asclepias amplexicaulis',
#  'a photo of a Asclepias syriaca',
#  'a photo of a Asclepias asperula',
#  'a photo of a Asclepias verticillata',
#  'a photo of a Asclepias oenotheroides',
#  'a photo of a Asclepias curassavica',
#  'a photo of a Asclepias viridiflora',
#  'a photo of a Asclepias viridis',
#  'a photo of a Asclepias linaria',
#  'a photo of a Asclepias subverticillata',
#  'a photo of a Oxalis drummondii',
#  'a photo of a Oxalis montana',
#  'a photo of a Oxalis obtusa',
#  'a photo of a Oxalis articulata',
#  'a photo of a Oxalis purpurea',
#  'a photo of a Oxalis dillenii',
#  'a photo of a Oxalis violacea',
#  'a photo of a Oxalis incarnata',
#  'a photo of a Oxalis acetosella',
#  'a photo of a Oxalis debilis',
#  'a photo of a Oxalis oregana',
#  'a photo of a Oxalis corniculata',
#  'a photo of a Oxalis pes-caprae',
#  'a photo of a Oxalis stricta',
#  'a photo of a Oxalis latifolia',
#  'a photo of a Euphorbia dentata',
#  'a photo of a Euphorbia cyathophora',
#  'a photo of a Euphorbia heterophylla',
#  'a photo of a Euphorbia corollata',
#  'a photo of a Euphorbia antisyphilitica',
#  'a photo of a Euphorbia bicolor',
#  'a photo of a Euphorbia marginata',
#  'a photo of a Euphorbia polycarpa',
#  'a photo of a Euphorbia hirta',
#  'a photo of a Euphorbia hyssopifolia',
#  'a photo of a Euphorbia albomarginata',
#  'a photo of a Euphorbia hypericifolia',
#  'a photo of a Euphorbia prostrata',
#  'a photo of a Euphorbia nutans',
#  'a photo of a Euphorbia serpens',
#  'a photo of a Euphorbia maculata',
#  'a photo of a Euphorbia myrsinites',
#  'a photo of a Euphorbia helioscopia',
#  'a photo of a Euphorbia characias',
#  'a photo of a Euphorbia lathyris',
#  'a photo of a Euphorbia oblongata',
#  'a photo of a Euphorbia peplus',
#  'a photo of a Euphorbia cyparissias',
#  'a photo of a Euphorbia virgata',
#  'a photo of a Euphorbia paralias',
#  'a photo of a Viola pedata',
#  'a photo of a Viola purpurea',
#  'a photo of a Viola sororia',
#  'a photo of a Viola pubescens',
#  'a photo of a Viola nuttallii',
#  'a photo of a Viola striata',
#  'a photo of a Viola canadensis',
#  'a photo of a Viola rostrata',
#  'a photo of a Viola adunca',
#  'a photo of a Viola tricolor',
#  'a photo of a Viola bicolor',
#  'a photo of a Viola labradorica',
#  'a photo of a Viola primulifolia',
#  'a photo of a Viola hastata',
#  'a photo of a Viola ocellata',
#  'a photo of a Viola sagittata',
#  'a photo of a Viola odorata',
#  'a photo of a Viola sempervirens',
#  'a photo of a Viola pedunculata',
#  'a photo of a Viola arvensis',
#  'a photo of a Viola lanceolata',
#  'a photo of a Viola rotundifolia',
#  'a photo of a Viola glabella',
#  'a photo of a Geranium caespitosum',
#  'a photo of a Geranium carolinianum',
#  'a photo of a Geranium richardsonii',
#  'a photo of a Geranium molle',
#  'a photo of a Geranium maculatum',
#  'a photo of a Geranium lucidum',
#  'a photo of a Geranium robertianum',
#  'a photo of a Geranium sylvaticum',
#  'a photo of a Geranium dissectum',
#  'a photo of a Geranium viscosissimum',
#  'a photo of a Geranium pratense',
#  'a photo of a Geranium sanguineum',
#  'a photo of a Quercus robur',
#  'a photo of a Quercus kelloggii',
#  'a photo of a Quercus alba',
#  'a photo of a Quercus stellata',
#  'a photo of a Quercus garryana',
#  'a photo of a Quercus ilex',
#  'a photo of a Quercus pagoda',
#  'a photo of a Quercus ilicifolia',
#  'a photo of a Quercus agrifolia',
#  'a photo of a Quercus berberidifolia',
#  'a photo of a Quercus nigra',
#  'a photo of a Quercus coccinea',
#  'a photo of a Quercus velutina',
#  'a photo of a Quercus rubra',
#  'a photo of a Quercus douglasii',
#  'a photo of a Quercus fusiformis',
#  'a photo of a Quercus buckleyi',
#  'a photo of a Quercus phellos',
#  'a photo of a Quercus durata',
#  'a photo of a Quercus michauxii',
#  'a photo of a Quercus wislizeni',
#  'a photo of a Quercus imbricaria',
#  'a photo of a Quercus montana',
#  'a photo of a Quercus chrysolepis',
#  'a photo of a Quercus marilandica',
#  'a photo of a Quercus laevis',
#  'a photo of a Quercus gambelii',
#  'a photo of a Quercus muehlenbergii',
#  'a photo of a Quercus macrocarpa',
#  'a photo of a Quercus bicolor',
#  'a photo of a Quercus shumardii',
#  'a photo of a Quercus palustris',
#  'a photo of a Quercus suber',
#  'a photo of a Quercus geminata',
#  'a photo of a Quercus falcata',
#  'a photo of a Quercus lobata',
#  'a photo of a Quercus turbinella',
#  'a photo of a Quercus virginiana',
#  'a photo of a Clematis drummondii',
#  'a photo of a Clematis lasiantha',
#  'a photo of a Clematis vitalba',
#  'a photo of a Clematis crispa',
#  'a photo of a Clematis texensis',
#  'a photo of a Clematis pitcheri',
#  'a photo of a Clematis terniflora',
#  'a photo of a Clematis virginiana',
#  'a photo of a Clematis paniculata',
#  'a photo of a Clematis ligusticifolia',
#  'a photo of a Clematis occidentalis',
#  'a photo of a Anemone hepatica',
#  'a photo of a Anemone acutiloba',
#  'a photo of a Anemone quinquefolia',
#  'a photo of a Anemone canadensis',
#  'a photo of a Anemone ranunculoides',
#  'a photo of a Anemone occidentalis',
#  'a photo of a Anemone multifida',
#  'a photo of a Anemone patens',
#  'a photo of a Anemone cylindrica',
#  'a photo of a Anemone berlandieri',
#  'a photo of a Anemone nemorosa',
#  'a photo of a Anemone virginiana',
#  'a photo of a Ranunculus fascicularis',
#  'a photo of a Ranunculus repens',
#  'a photo of a Ranunculus bulbosus',
#  'a photo of a Ranunculus glaberrimus',
#  'a photo of a Ranunculus acris',
#  'a photo of a Ranunculus californicus',
#  'a photo of a Ranunculus abortivus',
#  'a photo of a Ranunculus recurvatus',
#  'a photo of a Ranunculus muricatus',
#  'a photo of a Ranunculus sceleratus',
#  'a photo of a Ranunculus aquatilis',
#  'a photo of a Ranunculus hispidus',
#  'a photo of a Ranunculus flammula',
#  'a photo of a Ranunculus occidentalis',
#  'a photo of a Castilleja applegatei',
#  'a photo of a Castilleja linariifolia',
#  'a photo of a Castilleja chromosa',
#  'a photo of a Castilleja tenuiflora',
#  'a photo of a Castilleja foliolosa',
#  'a photo of a Castilleja miniata',
#  'a photo of a Castilleja attenuata',
#  'a photo of a Castilleja exserta',
#  'a photo of a Castilleja coccinea',
#  'a photo of a Castilleja affinis',
#  'a photo of a Castilleja indivisa',
#  'a photo of a Castilleja densiflora',
#  'a photo of a Castilleja arvensis',
#  'a photo of a Castilleja integra',
#  'a photo of a Castilleja rubicundula',
#  'a photo of a Castilleja purpurea',
#  'a photo of a Castilleja wightii',
#  'a photo of a Salvia ballotiflora',
#  'a photo of a Salvia coccinea',
#  'a photo of a Salvia dorrii',
#  'a photo of a Salvia mexicana',
#  'a photo of a Salvia farinacea',
#  'a photo of a Salvia azurea',
#  'a photo of a Salvia apiana',
#  'a photo of a Salvia roemeriana',
#  'a photo of a Salvia greggii',
#  'a photo of a Salvia microphylla',
#  'a photo of a Salvia texana',
#  'a photo of a Salvia columbariae',
#  'a photo of a Salvia leucophylla',
#  'a photo of a Salvia mellifera',
#  'a photo of a Salvia leucantha',
#  'a photo of a Salvia spathacea',
#  'a photo of a Salvia pratensis',
#  'a photo of a Salvia lyrata',
#  'a photo of a Verbena rigida',
#  'a photo of a Verbena stricta',
#  'a photo of a Verbena hastata',
#  'a photo of a Verbena officinalis',
#  'a photo of a Verbena brasiliensis',
#  'a photo of a Verbena bracteata',
#  'a photo of a Verbena bonariensis',
#  'a photo of a Verbena halei',
#  'a photo of a Verbena urticifolia',
#  'a photo of a Verbena lasiostachys',
#  'a photo of a Veronica hederifolia',
#  'a photo of a Veronica stricta',
#  'a photo of a Veronica polita',
#  'a photo of a Veronica persica',
#  'a photo of a Veronica filiformis',
#  'a photo of a Veronica officinalis',
#  'a photo of a Veronica chamaedrys',
#  'a photo of a Veronica arvensis',
#  'a photo of a Veronica regina-nivalis',
#  'a photo of a Veronica peregrina',
#  'a photo of a Veronica anagallis-aquatica',
#  'a photo of a Veronica americana',
#  'a photo of a Veronica serpyllifolia',
#  'a photo of a Penstemon centranthifolius',
#  'a photo of a Penstemon barbatus',
#  'a photo of a Penstemon spectabilis',
#  'a photo of a Penstemon cobaea',
#  'a photo of a Penstemon heterophyllus',
#  'a photo of a Penstemon hirsutus',
#  'a photo of a Penstemon newberryi',
#  'a photo of a Penstemon palmeri',
#  'a photo of a Penstemon digitalis',
#  'a photo of a Penstemon eatonii',
#  'a photo of a Solanum pseudocapsicum',
#  'a photo of a Solanum rostratum',
#  'a photo of a Solanum chenopodioides',
#  'a photo of a Solanum laciniatum',
#  'a photo of a Solanum erianthum',
#  'a photo of a Solanum umbelliferum',
#  'a photo of a Solanum xanti',
#  'a photo of a Solanum nigrum',
#  'a photo of a Solanum triquetrum',
#  'a photo of a Solanum douglasii',
#  'a photo of a Solanum americanum',
#  'a photo of a Solanum ptychanthum',
#  'a photo of a Solanum carolinense',
#  'a photo of a Solanum mauritianum',
#  'a photo of a Solanum diphyllum',
#  'a photo of a Solanum elaeagnifolium',
#  'a photo of a Solanum dimidiatum',
#  'a photo of a Solanum lycopersicum',
#  'a photo of a Solanum dulcamara',
#  'a photo of a Ipomoea cairica',
#  'a photo of a Ipomoea batatas',
#  'a photo of a Ipomoea triloba',
#  'a photo of a Ipomoea pes-caprae',
#  'a photo of a Ipomoea imperati',
#  'a photo of a Ipomoea hederacea',
#  'a photo of a Ipomoea indica',
#  'a photo of a Ipomoea sagittata',
#  'a photo of a Ipomoea cordatotriloba',
#  'a photo of a Ipomoea lacunosa',
#  'a photo of a Ipomoea alba',
#  'a photo of a Ipomoea hederifolia',
#  'a photo of a Ipomoea pandurata',
#  'a photo of a Ipomoea purpurea',
#  'a photo of a Ipomoea quamoclit',
#  'a photo of a Ipomoea obscura',
#  'a photo of a Rosa rugosa',
#  'a photo of a Rosa carolina',
#  'a photo of a Rosa multiflora',
#  'a photo of a Rosa nutkana',
#  'a photo of a Rosa woodsii',
#  'a photo of a Rosa palustris',
#  'a photo of a Rosa gymnocarpa',
#  'a photo of a Rosa bracteata',
#  'a photo of a Rosa arkansana',
#  'a photo of a Rosa canina',
#  'a photo of a Rosa acicularis',
#  'a photo of a Rosa californica',
#  'a photo of a Rubus parviflorus',
#  'a photo of a Rubus allegheniensis',
#  'a photo of a Rubus arcticus',
#  'a photo of a Rubus fruticosus',
#  'a photo of a Rubus caesius',
#  'a photo of a Rubus spectabilis',
#  'a photo of a Rubus leucodermis',
#  'a photo of a Rubus odoratus',
#  'a photo of a Rubus armeniacus',
#  'a photo of a Rubus pubescens',
#  'a photo of a Rubus ursinus',
#  'a photo of a Rubus cissoides',
#  'a photo of a Rubus chamaemorus',
#  'a photo of a Rubus laciniatus',
#  'a photo of a Rubus idaeus',
#  'a photo of a Rubus phoenicolasius',
#  'a photo of a Rubus trivialis',
#  'a photo of a Rubus flagellaris',
#  'a photo of a Rubus occidentalis',
#  'a photo of a Rubus pedatus',
#  'a photo of a Prunus avium',
#  'a photo of a Prunus padus',
#  'a photo of a Prunus americana',
#  'a photo of a Prunus caroliniana',
#  'a photo of a Prunus spinosa',
#  'a photo of a Prunus cerasifera',
#  'a photo of a Prunus persica',
#  'a photo of a Prunus emarginata',
#  'a photo of a Prunus laurocerasus',
#  'a photo of a Prunus virginiana',
#  'a photo of a Prunus serotina',
#  'a photo of a Prunus pensylvanica',
#  'a photo of a Prunus ilicifolia',
#  'a photo of a Prunus mexicana',
#  'a photo of a Prunus pumila',
#  'a photo of a Potentilla argentea',
#  'a photo of a Potentilla reptans',
#  'a photo of a Potentilla simplex',
#  'a photo of a Potentilla gracilis',
#  'a photo of a Potentilla recta',
#  'a photo of a Potentilla norvegica',
#  'a photo of a Potentilla anserina',
#  'a photo of a Potentilla erecta',
#  'a photo of a Potentilla indica',
#  'a photo of a Potentilla canadensis',
#  'a photo of a Cardamine californica',
#  'a photo of a Cardamine diphylla',
#  'a photo of a Cardamine nuttallii',
#  'a photo of a Cardamine concatenata',
#  'a photo of a Cardamine pratensis',
#  'a photo of a Cardamine impatiens',
#  'a photo of a Cardamine bulbosa',
#  'a photo of a Cardamine hirsuta',
#  'a photo of a Cardamine flexuosa',
#  'a photo of a Cardamine douglassii',
#  'a photo of a Trillium recurvatum',
#  'a photo of a Trillium luteum',
#  'a photo of a Trillium ovatum',
#  'a photo of a Trillium flexipes',
#  'a photo of a Trillium erectum',
#  'a photo of a Trillium albidum',
#  'a photo of a Trillium cuneatum',
#  'a photo of a Trillium undulatum',
#  'a photo of a Trillium chloropetalum',
#  'a photo of a Trillium cernuum',
#  'a photo of a Trillium catesbaei',
#  'a photo of a Trillium grandiflorum',
#  'a photo of a Trillium sessile',
#  'a photo of a Calochortus catalinae',
#  'a photo of a Calochortus leichtlinii',
#  'a photo of a Calochortus weedii',
#  'a photo of a Calochortus pulchellus',
#  'a photo of a Calochortus venustus',
#  'a photo of a Calochortus amabilis',
#  'a photo of a Calochortus gunnisonii',
#  'a photo of a Calochortus splendens',
#  'a photo of a Calochortus albus',
#  'a photo of a Calochortus umbellatus',
#  'a photo of a Calochortus nuttallii',
#  'a photo of a Calochortus tolmiei',
#  'a photo of a Calochortus luteus',
#  'a photo of a Calochortus uniflorus',
#  'a photo of a Smilax laurifolia',
#  'a photo of a Smilax auriculata',
#  'a photo of a Smilax glauca',
#  'a photo of a Smilax aspera',
#  'a photo of a Smilax tamnoides',
#  'a photo of a Smilax rotundifolia',
#  'a photo of a Smilax lasioneura',
#  'a photo of a Smilax smallii',
#  'a photo of a Smilax herbacea',
#  'a photo of a Smilax bona-nox',
#  'a photo of a Carex grayi',
#  'a photo of a Carex lupulina',
#  'a photo of a Carex intumescens',
#  'a photo of a Carex flava',
#  'a photo of a Carex vulpinoidea',
#  'a photo of a Carex pensylvanica',
#  'a photo of a Carex hystericina',
#  'a photo of a Carex obnupta',
#  'a photo of a Carex crinita',
#  'a photo of a Carex plantaginea',
#  'a photo of a Carex pendula',
#  'a photo of a Carex aurea',
#  'a photo of a Carex gracillima',
#  'a photo of a Carex cherokeensis',
#  'a photo of a Carex sprengelii',
#  'a photo of a Iris cristata',
#  'a photo of a Iris douglasiana',
#  'a photo of a Iris missouriensis',
#  'a photo of a Iris pseudacorus',
#  'a photo of a Iris macrosiphon',
#  'a photo of a Iris tenax',
#  'a photo of a Iris virginica',
#  'a photo of a Iris germanica',
#  'a photo of a Iris foetidissima',
#  'a photo of a Iris versicolor',
#  'a photo of a Yucca filamentosa',
#  'a photo of a Yucca arkansana',
#  'a photo of a Yucca elata',
#  'a photo of a Yucca pallida',
#  'a photo of a Yucca treculeana',
#  'a photo of a Yucca brevifolia',
#  'a photo of a Yucca glauca',
#  'a photo of a Yucca schidigera',
#  'a photo of a Yucca baccata',
#  'a photo of a Yucca rupicola',
#  'a photo of a Pinus flexilis',
#  'a photo of a Pinus lambertiana',
#  'a photo of a Pinus monticola',
#  'a photo of a Pinus strobus',
#  'a photo of a Pinus edulis',
#  'a photo of a Pinus monophylla',
#  'a photo of a Pinus longaeva',
#  'a photo of a Pinus jeffreyi',
#  'a photo of a Pinus ponderosa',
#  'a photo of a Pinus taeda',
#  'a photo of a Pinus torreyana',
#  'a photo of a Pinus coulteri',
#  'a photo of a Pinus virginiana',
#  'a photo of a Pinus rigida',
#  'a photo of a Pinus sabiniana',
#  'a photo of a Pinus palustris',
#  'a photo of a Pinus radiata',
#  'a photo of a Pinus elliottii',
#  'a photo of a Pinus contorta',
#  'a photo of a Pinus banksiana',
#  'a photo of a Pinus echinata',
#  'a photo of a Pinus resinosa',
#  'a photo of a Pinus sylvestris',
#  'a photo of a Asplenium platyneuron',
#  'a photo of a Asplenium polyodon',
#  'a photo of a Asplenium trichomanes',
#  'a photo of a Asplenium flabellifolium',
#  ...]

# %%
import open_clip

# Load the BioCLIP model and its preprocessors
model, _, preprocess = open_clip.create_model_and_transforms('hf-hub:imageomics/bioclip')
model.eval()  # Ensure model is in evaluation mode = open_clip.create_model_and_transforms('hf-hub:imageomics/bioclip')
tokenizer = open_clip.get_tokenizer('hf-hub:imageomics/bioclip')
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|---------------------------------------------------------------------------|\n| Active memory         |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|---------------------------------------------------------------------------|\n| Requested memory      |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |\n|---------------------------------------------------------------------------|\n| Allocations           |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Active allocs         |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
#label_tokens = tokenizer(clip_labels, return_tensors='pt', padding=True)
model.to("cuda")
# Out:
# CLIP(
#   (visual): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16), bias=False)
#     (patch_dropout): Identity()
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): ModuleList(
#         (0-11): 12 x ResidualAttentionBlock(
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ls_1): Identity()
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): GELU(approximate='none')
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ls_2): Identity()
#         )
#       )
#     )
#     (ln_post): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer): Transformer(
#     (resblocks): ModuleList(
#       (0-11): 12 x ResidualAttentionBlock(
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ls_1): Identity()
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ls_2): Identity()
#       )
#     )
#   )
#   (token_embedding): Embedding(49408, 512)
#   (ln_final): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
# )

# %%
# from torchvision.transforms import Resize

# # Resize images before preprocessing
# resize = Resize((256, 256))  # Adjust size as necessary

# # Modify image loading and preprocessing
# images = [resize(Image.open(image_paths[j])) for j in range(i, i_end)]
# image_tensors = torch.stack([preprocess(image).unsqueeze(0) for image in images]).to(model.device)

# %%
image_dir = '/scratch/ssd004/scratch/junejory/val2019'
image_paths = []
image_labels = []


for annotation in annotations['annotations']:
    image_info = next(image for image in annotations['images'] if image['id'] == annotation['image_id'])
    image_path = os.path.join(image_dir, image_info['file_name'])
    image_paths.append(image_path)
    image_labels.append(annotation['category_id'])

# %%
image_labels
# Out:
# [644,
#  597,
#  883,
#  300,
#  881,
#  771,
#  607,
#  698,
#  714,
#  316,
#  726,
#  27,
#  640,
#  756,
#  73,
#  594,
#  179,
#  440,
#  859,
#  5,
#  401,
#  928,
#  216,
#  200,
#  983,
#  350,
#  223,
#  438,
#  834,
#  248,
#  127,
#  451,
#  828,
#  893,
#  456,
#  811,
#  272,
#  627,
#  291,
#  960,
#  583,
#  217,
#  17,
#  637,
#  99,
#  703,
#  18,
#  458,
#  1000,
#  499,
#  704,
#  276,
#  611,
#  719,
#  584,
#  1005,
#  511,
#  886,
#  938,
#  370,
#  482,
#  79,
#  367,
#  254,
#  605,
#  860,
#  382,
#  384,
#  420,
#  821,
#  548,
#  944,
#  484,
#  41,
#  963,
#  574,
#  320,
#  144,
#  786,
#  549,
#  981,
#  47,
#  434,
#  194,
#  629,
#  119,
#  812,
#  105,
#  431,
#  282,
#  759,
#  295,
#  83,
#  469,
#  59,
#  499,
#  965,
#  496,
#  364,
#  309,
#  740,
#  412,
#  53,
#  915,
#  882,
#  585,
#  167,
#  82,
#  772,
#  35,
#  268,
#  776,
#  855,
#  668,
#  43,
#  16,
#  171,
#  114,
#  166,
#  57,
#  786,
#  977,
#  301,
#  503,
#  858,
#  690,
#  385,
#  985,
#  11,
#  637,
#  72,
#  305,
#  327,
#  465,
#  551,
#  657,
#  418,
#  644,
#  533,
#  104,
#  442,
#  389,
#  413,
#  734,
#  123,
#  303,
#  680,
#  617,
#  328,
#  51,
#  419,
#  514,
#  621,
#  290,
#  466,
#  110,
#  397,
#  697,
#  426,
#  323,
#  509,
#  892,
#  341,
#  140,
#  313,
#  79,
#  175,
#  850,
#  378,
#  870,
#  410,
#  965,
#  285,
#  228,
#  655,
#  217,
#  743,
#  421,
#  911,
#  1003,
#  905,
#  177,
#  319,
#  576,
#  392,
#  274,
#  632,
#  723,
#  872,
#  428,
#  355,
#  676,
#  917,
#  435,
#  902,
#  55,
#  635,
#  984,
#  757,
#  451,
#  303,
#  330,
#  494,
#  867,
#  228,
#  248,
#  183,
#  221,
#  447,
#  502,
#  77,
#  526,
#  432,
#  554,
#  294,
#  271,
#  461,
#  225,
#  699,
#  321,
#  5,
#  187,
#  13,
#  851,
#  114,
#  504,
#  879,
#  332,
#  100,
#  302,
#  385,
#  735,
#  142,
#  132,
#  310,
#  243,
#  755,
#  4,
#  813,
#  539,
#  765,
#  113,
#  980,
#  736,
#  49,
#  151,
#  13,
#  490,
#  276,
#  288,
#  837,
#  716,
#  135,
#  205,
#  471,
#  437,
#  60,
#  20,
#  54,
#  530,
#  131,
#  55,
#  649,
#  933,
#  217,
#  565,
#  270,
#  367,
#  997,
#  537,
#  810,
#  165,
#  439,
#  802,
#  869,
#  807,
#  664,
#  163,
#  606,
#  444,
#  399,
#  341,
#  233,
#  497,
#  363,
#  479,
#  980,
#  220,
#  523,
#  407,
#  404,
#  672,
#  642,
#  298,
#  197,
#  966,
#  991,
#  931,
#  995,
#  141,
#  190,
#  381,
#  134,
#  646,
#  620,
#  533,
#  386,
#  365,
#  123,
#  805,
#  61,
#  853,
#  121,
#  431,
#  951,
#  572,
#  806,
#  278,
#  285,
#  82,
#  602,
#  778,
#  691,
#  155,
#  29,
#  730,
#  335,
#  751,
#  359,
#  58,
#  75,
#  788,
#  710,
#  723,
#  295,
#  353,
#  744,
#  89,
#  142,
#  951,
#  911,
#  168,
#  717,
#  109,
#  823,
#  902,
#  445,
#  971,
#  7,
#  540,
#  724,
#  604,
#  836,
#  934,
#  378,
#  10,
#  332,
#  137,
#  622,
#  238,
#  703,
#  331,
#  897,
#  161,
#  800,
#  233,
#  420,
#  694,
#  986,
#  786,
#  284,
#  295,
#  865,
#  880,
#  470,
#  147,
#  479,
#  154,
#  806,
#  793,
#  758,
#  352,
#  373,
#  688,
#  324,
#  591,
#  495,
#  235,
#  771,
#  441,
#  969,
#  926,
#  244,
#  478,
#  446,
#  192,
#  332,
#  779,
#  996,
#  994,
#  916,
#  686,
#  699,
#  238,
#  819,
#  253,
#  682,
#  199,
#  748,
#  553,
#  156,
#  561,
#  190,
#  745,
#  1,
#  189,
#  919,
#  365,
#  406,
#  279,
#  627,
#  397,
#  468,
#  389,
#  1000,
#  800,
#  131,
#  293,
#  614,
#  818,
#  450,
#  509,
#  647,
#  657,
#  866,
#  893,
#  501,
#  268,
#  567,
#  690,
#  458,
#  532,
#  600,
#  729,
#  784,
#  145,
#  306,
#  657,
#  603,
#  777,
#  642,
#  148,
#  877,
#  448,
#  949,
#  517,
#  450,
#  258,
#  405,
#  358,
#  713,
#  535,
#  306,
#  474,
#  1009,
#  584,
#  762,
#  621,
#  593,
#  760,
#  226,
#  952,
#  946,
#  647,
#  916,
#  845,
#  125,
#  327,
#  834,
#  463,
#  623,
#  120,
#  924,
#  289,
#  932,
#  881,
#  133,
#  302,
#  464,
#  362,
#  689,
#  732,
#  193,
#  362,
#  134,
#  305,
#  176,
#  854,
#  225,
#  286,
#  774,
#  794,
#  554,
#  515,
#  525,
#  206,
#  256,
#  841,
#  756,
#  396,
#  749,
#  687,
#  913,
#  890,
#  36,
#  349,
#  769,
#  96,
#  342,
#  984,
#  230,
#  866,
#  12,
#  983,
#  542,
#  507,
#  972,
#  494,
#  326,
#  372,
#  358,
#  249,
#  484,
#  808,
#  989,
#  496,
#  235,
#  880,
#  291,
#  767,
#  449,
#  646,
#  851,
#  860,
#  521,
#  925,
#  490,
#  506,
#  612,
#  768,
#  267,
#  418,
#  856,
#  12,
#  940,
#  624,
#  660,
#  269,
#  957,
#  294,
#  767,
#  63,
#  258,
#  799,
#  720,
#  440,
#  794,
#  617,
#  119,
#  26,
#  499,
#  493,
#  580,
#  667,
#  987,
#  1003,
#  380,
#  53,
#  24,
#  759,
#  997,
#  223,
#  788,
#  123,
#  412,
#  937,
#  158,
#  455,
#  97,
#  402,
#  992,
#  683,
#  447,
#  1008,
#  197,
#  685,
#  304,
#  511,
#  304,
#  69,
#  57,
#  738,
#  765,
#  110,
#  764,
#  550,
#  449,
#  608,
#  962,
#  830,
#  67,
#  715,
#  559,
#  999,
#  263,
#  887,
#  143,
#  202,
#  776,
#  246,
#  609,
#  668,
#  251,
#  452,
#  508,
#  337,
#  872,
#  577,
#  871,
#  200,
#  689,
#  770,
#  938,
#  459,
#  679,
#  653,
#  360,
#  838,
#  148,
#  671,
#  300,
#  138,
#  741,
#  94,
#  534,
#  122,
#  912,
#  415,
#  622,
#  359,
#  292,
#  309,
#  698,
#  280,
#  368,
#  826,
#  580,
#  601,
#  444,
#  528,
#  481,
#  340,
#  155,
#  522,
#  789,
#  852,
#  717,
#  924,
#  288,
#  377,
#  598,
#  182,
#  142,
#  435,
#  266,
#  236,
#  889,
#  902,
#  212,
#  246,
#  859,
#  722,
#  183,
#  218,
#  227,
#  69,
#  570,
#  180,
#  350,
#  132,
#  124,
#  895,
#  224,
#  676,
#  1001,
#  792,
#  689,
#  672,
#  135,
#  306,
#  747,
#  481,
#  545,
#  577,
#  450,
#  410,
#  566,
#  15,
#  936,
#  383,
#  442,
#  205,
#  112,
#  852,
#  173,
#  115,
#  346,
#  41,
#  641,
#  390,
#  338,
#  775,
#  947,
#  126,
#  890,
#  535,
#  650,
#  586,
#  702,
#  352,
#  518,
#  279,
#  373,
#  47,
#  753,
#  680,
#  16,
#  229,
#  922,
#  174,
#  739,
#  190,
#  299,
#  344,
#  640,
#  950,
#  534,
#  692,
#  493,
#  648,
#  438,
#  740,
#  251,
#  502,
#  910,
#  395,
#  961,
#  998,
#  843,
#  706,
#  898,
#  261,
#  960,
#  673,
#  810,
#  467,
#  74,
#  107,
#  586,
#  736,
#  595,
#  965,
#  933,
#  147,
#  920,
#  464,
#  457,
#  560,
#  975,
#  343,
#  331,
#  34,
#  611,
#  348,
#  634,
#  27,
#  273,
#  815,
#  194,
#  185,
#  831,
#  939,
#  9,
#  322,
#  404,
#  35,
#  102,
#  959,
#  742,
#  664,
#  974,
#  923,
#  201,
#  33,
#  443,
#  901,
#  929,
#  733,
#  825,
#  567,
#  926,
#  505,
#  350,
#  530,
#  663,
#  908,
#  368,
#  980,
#  618,
#  591,
#  185,
#  990,
#  987,
#  747,
#  280,
#  915,
#  639,
#  206,
#  518,
#  176,
#  938,
#  825,
#  953,
#  101,
#  722,
#  470,
#  817,
#  1001,
#  678,
#  928,
#  168,
#  897,
#  674,
#  809,
#  927,
#  36,
#  264,
#  666,
#  726,
#  83,
#  701,
#  519,
#  24,
#  555,
#  565,
#  744,
#  870,
#  23,
#  732,
#  906,
#  773,
#  706,
#  439,
#  94,
#  23,
#  547,
#  291,
#  731,
#  683,
#  735,
#  658,
#  716,
#  610,
#  433,
#  128,
#  91,
#  802,
#  311,
#  43,
#  733,
#  98,
#  25,
#  922,
#  802,
#  324,
#  484,
#  63,
#  569,
#  93,
#  502,
#  425,
#  633,
#  662,
#  456,
#  890,
#  831,
#  569,
#  891,
#  20,
#  91,
#  452,
#  297,
#  407,
#  30,
#  185,
#  251,
#  557,
#  804,
#  675,
#  428,
#  160,
#  909,
#  681,
#  108,
#  711,
#  130,
#  86,
#  269,
#  158,
#  129,
#  338,
#  130,
#  478,
#  179,
#  909,
#  201,
#  231,
#  214,
#  916,
#  396,
#  201,
#  243,
#  290,
#  406,
#  243,
#  414,
#  58,
#  855,
#  478,
#  488,
#  848,
#  687,
#  649,
#  826,
#  45,
#  69,
#  39,
#  488,
#  921,
#  868,
#  308,
#  188,
#  509,
#  419,
#  558,
#  671,
#  249,
#  940,
#  787,
#  879,
#  108,
#  180,
#  22,
#  210,
#  56,
#  646,
#  186,
#  342,
#  76,
#  588,
#  293,
#  247,
#  882,
#  641,
#  369,
#  560,
#  487,
#  766,
#  825,
#  861,
#  540,
#  725,
#  589,
#  270,
#  849,
#  591,
#  387,
#  30,
#  950,
#  678,
#  183,
#  581,
#  325,
#  445,
#  812,
#  619,
#  552,
#  224,
#  403,
#  376,
#  ...]

# %%
tokenized_labels = tokenizer(clip_labels).to(device)

# Ensure tokenized labels are in the right format
# Note: This assumes the tokenizer returns a tensor of shape [num_labels, max_seq_length]
if tokenized_labels.ndimension() == 1:
    tokenized_labels = tokenized_labels.unsqueeze(0)

# Get the label embeddings
with torch.no_grad():
    label_emb = model.encode_text(tokenized_labels)

# label_embeddings now contains the embeddings for your labels
label_emb /= label_emb.norm(dim=-1, keepdim=True)

print(label_emb.shape)
# Out:
# torch.Size([1010, 512])

# %%
for image_path, label_id in zip(image_paths, image_labels):
    # Load and preprocess image
    image = preprocess(Image.open(image_path)).unsqueeze(0)

# %%
preds = []
batch_size = 32

for i in tqdm(range(0, len(image_paths), batch_size)):
    i_end = min(i + batch_size, len(image_paths))
    images = [Image.open(image_paths[j]) for j in range(i, i_end)]
    image_tensors = torch.stack([preprocess(image) for image in images]).to(device)

    with torch.no_grad(), torch.cuda.amp.autocast():
        img_emb = model.encode_image(image_tensors)
        img_emb /= img_emb.norm(dim=-1, keepdim=True)
        scores = (100.0 * img_emb @ label_emb.T).softmax(dim=-1)

    batch_preds = torch.argmax(scores, dim=1).cpu().numpy()
    preds.extend(batch_preds)

# Calculate accuracy
correct = sum(1 for pred, label in zip(preds, image_labels) if pred == label)
accuracy = correct / len(image_labels)
print(f"Accuracy: {accuracy:.4f}")
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]
# Accuracy: 0.7063
